# %%
from bigquery_config import get_client, PROJECT_ID
from bigquery_upload import list_csv_files, upload_file
from bigquery_query import list_tables, get_table_info, query_table, run_query, insert_rows

# %%
# Xem danh sách file CSV con trong thư mục data
DATASET = "K312"
list_csv_files()

# %%
# Upload 1 số file theo ý muốn

files_to_upload = [
    "address.csv",
    "customer.csv",
]

upload_file(DATASET, files_to_upload)

# %%
# list_tables(DATASET)
# get_table_info(DATASET, "address")
address = run_query(f"""
        SELECT *
        FROM `{PROJECT_ID}.{DATASET}.address`
        ORDER BY 1 ASC
        LIMIT 5
    """)
address
# Out:
# ⏳ Đang chạy query...
# c:\Users\HuyenTong\Desktop\In Progress\Git\Git-Google-Platform\venv\Lib\site-packages\google\cloud\bigquery\table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# ✅ Xong! Trả về 5 rows
#    address_id               address        city postal_code    country  \
# 0           1     47 MySakila Drive  Lethbridge        NULL     Canada
# 1           2    28 MySQL Boulevard   Woodridge        NULL  Australia
# 2           3     23 Workhaven Lane  Lethbridge        NULL     Canada
# 3           4  1411 Lillydale Drive   Woodridge        NULL  Australia
# 4           5        1913 Hanoi Way      Sasebo       35200      Japan
#
#                 last_update
# 0 2006-02-15 04:45:30+00:00
# 1 2006-02-15 04:45:30+00:00
# 2 2006-02-15 04:45:30+00:00
# 3 2006-02-15 04:45:30+00:00
# 4 2006-02-15 04:45:30+00:00
